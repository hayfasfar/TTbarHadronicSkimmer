# %%
from coffea.nanoevents import NanoEventsFactory, NanoAODSchema

# Set the file to inspect — swap in any path from qcd.json
filename = "/store/mc/Run3Winter24NanoAOD/QCD_PT-15to7000_TuneCP5_Flat2022_13p6TeV_pythia8/NANOAODSIM/JMENanoV14_133X_mcRun3_2024_realistic_v10-v1/2530000/01eebb7d-8f73-4e7a-baae-83c9ff84af44.root"
filename = "/store/mc/RunIII2024Summer24NanoAODv15/QCD_Bin-PT-15to7000_Par-PT-Flat_TuneCH3_13p6TeV_herwig7/NANOAODSIM/150X_mcRun3_2024_realistic_v2-v2/2820000/005f8b3c-b044-48c0-bf57-77db0939ade4.root"
redirector = "root://xcache/"

events = NanoEventsFactory.from_root(
    {redirector + filename: "Events"},
    schemaclass=NanoAODSchema,
    entry_stop=1,  # only need 1 event to read schema
).events()

# %%
print("=== Top-level event fields ===")
print(sorted(events.fields))
# Out:
# === Top-level event fields ===
# ['BeamSpot', 'CaloMET', 'CorrT1METJet', 'DST', 'Dataset', 'DeepMETResolutionTune', 'DeepMETResponseTune', 'Electron', 'FatJet', 'FatJetPFCand', 'FiducialMET', 'Flag', 'FsrPhoton', 'GenDressedLepton', 'GenIsolatedPhoton', 'GenJet', 'GenJetAK8', 'GenMET', 'GenPart', 'GenProton', 'GenVisTau', 'GenVtx', 'Generator', 'HLT', 'HLTriggerFinalPath', 'HLTriggerFirstPath', 'HTXS', 'IsoTrack', 'Jet', 'L1', 'L1Reco', 'L1simulation', 'LowPtElectron', 'MC', 'Muon', 'OtherPV', 'PFCand', 'PFMET', 'PSWeight', 'PV', 'PVBS', 'Photon', 'Pileup', 'PuppiMET', 'RawPFMET', 'RawPuppiMET', 'Rho', 'SV', 'SoftActivityJet', 'SoftActivityJetHT', 'SoftActivityJetHT10', 'SoftActivityJetHT2', 'SoftActivityJetHT5', 'SoftActivityJetNjets10', 'SoftActivityJetNjets2', 'SoftActivityJetNjets5', 'SubGenJetAK8', 'SubJet', 'Tau', 'TauProd', 'TauSpinner', 'TrackGenJetAK4', 'TrigObj', 'TrkMET', 'boostedTau', 'bunchCrossing', 'event', 'genTtbarId', 'genWeight', 'luminosityBlock', 'orbitNumber', 'run']

# %%
print("=== FatJet fields ===")
for f in sorted(events.FatJet.fields):
    print(f"  FatJet_{f}")
# Out:
# === FatJet fields ===
#   FatJet_area
#   FatJet_chEmEF
#   FatJet_chHEF
#   FatJet_chMultiplicity
#   FatJet_electronIdx3SJ
#   FatJet_eta
#   FatJet_genJetAK8Idx
#   FatJet_genJetAK8IdxG
#   FatJet_globalParT3_QCD
#   FatJet_globalParT3_TopbWev
#   FatJet_globalParT3_TopbWmv
#   FatJet_globalParT3_TopbWq
#   FatJet_globalParT3_TopbWqq
#   FatJet_globalParT3_TopbWtauhv
#   FatJet_globalParT3_WvsQCD
#   FatJet_globalParT3_XWW3q
#   FatJet_globalParT3_XWW4q
#   FatJet_globalParT3_XWWqqev
#   FatJet_globalParT3_XWWqqmv
#   FatJet_globalParT3_Xbb
#   FatJet_globalParT3_Xcc
#   FatJet_globalParT3_Xcs
#   FatJet_globalParT3_Xqq
#   FatJet_globalParT3_Xtauhtaue
#   FatJet_globalParT3_Xtauhtauh
#   FatJet_globalParT3_Xtauhtaum
#   FatJet_globalParT3_massCorrGeneric
#   FatJet_globalParT3_massCorrX2p
#   FatJet_globalParT3_withMassTopvsQCD
#   FatJet_globalParT3_withMassWvsQCD
#   FatJet_globalParT3_withMassZvsQCD
#   FatJet_hadronFlavour
#   FatJet_hfEmEF
#   FatJet_hfHEF
#   FatJet_lsf3
#   FatJet_mass
#   FatJet_msoftdrop
#   FatJet_muEF
#   FatJet_muonIdx3SJ
#   FatJet_n2b1
#   FatJet_n3b1
#   FatJet_nConstituents
#   FatJet_neEmEF
#   FatJet_neHEF
#   FatJet_neMultiplicity
#   FatJet_particleNetLegacy_QCD
#   FatJet_particleNetLegacy_Xbb
#   FatJet_particleNetLegacy_Xcc
#   FatJet_particleNetLegacy_Xqq
#   FatJet_particleNetLegacy_mass
#   FatJet_particleNetWithMass_H4qvsQCD
#   FatJet_particleNetWithMass_HbbvsQCD
#   FatJet_particleNetWithMass_HccvsQCD
#   FatJet_particleNetWithMass_QCD
#   FatJet_particleNetWithMass_TvsQCD
#   FatJet_particleNetWithMass_WvsQCD
#   FatJet_particleNetWithMass_ZvsQCD
#   FatJet_particleNet_QCD
#   FatJet_particleNet_QCD0HF
#   FatJet_particleNet_QCD1HF
#   FatJet_particleNet_QCD2HF
#   FatJet_particleNet_WVsQCD
#   FatJet_particleNet_XbbVsQCD
#   FatJet_particleNet_XccVsQCD
#   FatJet_particleNet_XggVsQCD
#   FatJet_particleNet_XqqVsQCD
#   FatJet_particleNet_XteVsQCD
#   FatJet_particleNet_XtmVsQCD
#   FatJet_particleNet_XttVsQCD
#   FatJet_particleNet_massCorr
#   FatJet_phi
#   FatJet_pt
#   FatJet_rawFactor
#   FatJet_subJetIdx1
#   FatJet_subJetIdx1G
#   FatJet_subJetIdx2
#   FatJet_subJetIdx2G
#   FatJet_subJetIdxG
#   FatJet_tau1
#   FatJet_tau2
#   FatJet_tau3
#   FatJet_tau4

# %%
print("=== FatJet tagger-related fields ===")
keywords = ["top", "ttag", "particleNet", "globalParT", "deepTag", "ParT", "Xtt", "Top"]
for f in sorted(events.FatJet.fields):
    if any(k.lower() in f.lower() for k in keywords):
        print(f"  FatJet_{f}")
# Out:
# === FatJet tagger-related fields ===
#   FatJet_globalParT3_QCD
#   FatJet_globalParT3_TopbWev
#   FatJet_globalParT3_TopbWmv
#   FatJet_globalParT3_TopbWq
#   FatJet_globalParT3_TopbWqq
#   FatJet_globalParT3_TopbWtauhv
#   FatJet_globalParT3_WvsQCD
#   FatJet_globalParT3_XWW3q
#   FatJet_globalParT3_XWW4q
#   FatJet_globalParT3_XWWqqev
#   FatJet_globalParT3_XWWqqmv
#   FatJet_globalParT3_Xbb
#   FatJet_globalParT3_Xcc
#   FatJet_globalParT3_Xcs
#   FatJet_globalParT3_Xqq
#   FatJet_globalParT3_Xtauhtaue
#   FatJet_globalParT3_Xtauhtauh
#   FatJet_globalParT3_Xtauhtaum
#   FatJet_globalParT3_massCorrGeneric
#   FatJet_globalParT3_massCorrX2p
#   FatJet_globalParT3_withMassTopvsQCD
#   FatJet_globalParT3_withMassWvsQCD
#   FatJet_globalParT3_withMassZvsQCD
#   FatJet_particleNetLegacy_QCD
#   FatJet_particleNetLegacy_Xbb
#   FatJet_particleNetLegacy_Xcc
#   FatJet_particleNetLegacy_Xqq
#   FatJet_particleNetLegacy_mass
#   FatJet_particleNetWithMass_H4qvsQCD
#   FatJet_particleNetWithMass_HbbvsQCD
#   FatJet_particleNetWithMass_HccvsQCD
#   FatJet_particleNetWithMass_QCD
#   FatJet_particleNetWithMass_TvsQCD
#   FatJet_particleNetWithMass_WvsQCD
#   FatJet_particleNetWithMass_ZvsQCD
#   FatJet_particleNet_QCD
#   FatJet_particleNet_QCD0HF
#   FatJet_particleNet_QCD1HF
#   FatJet_particleNet_QCD2HF
#   FatJet_particleNet_WVsQCD
#   FatJet_particleNet_XbbVsQCD
#   FatJet_particleNet_XccVsQCD
#   FatJet_particleNet_XggVsQCD
#   FatJet_particleNet_XqqVsQCD
#   FatJet_particleNet_XteVsQCD
#   FatJet_particleNet_XtmVsQCD
#   FatJet_particleNet_XttVsQCD
#   FatJet_particleNet_massCorr
